# %%
import pandas as pd

# %%
raw_csv_data = pd.read_csv('Absenteeism-data.csv')

# %%
raw_csv_data
# Out:
#      ID  Reason for Absence        Date  Transportation Expense  \
# 0    11                  26  07/07/2015                     289
# 1    36                   0  14/07/2015                     118
# 2     3                  23  15/07/2015                     179
# 3     7                   7  16/07/2015                     279
# 4    11                  23  23/07/2015                     289
# 5     3                  23  10/07/2015                     179
# 6    10                  22  17/07/2015                     361
# 7    20                  23  24/07/2015                     260
# 8    14                  19  06/07/2015                     155
# 9     1                  22  13/07/2015                     235
# 10   20                   1  20/07/2015                     260
# 11   20                   1  14/07/2015                     260
# 12   20                  11  15/07/2015                     260
# 13    3                  11  15/07/2015                     179
# ...

# %% [markdown]
# **Always** make a copy of your initial dataset when you begin.

# %%
df = raw_csv_data.copy()

# %%
df
# Out:
#      ID  Reason for Absence        Date  Transportation Expense  \
# 0    11                  26  07/07/2015                     289
# 1    36                   0  14/07/2015                     118
# 2     3                  23  15/07/2015                     179
# 3     7                   7  16/07/2015                     279
# 4    11                  23  23/07/2015                     289
# 5     3                  23  10/07/2015                     179
# 6    10                  22  17/07/2015                     361
# 7    20                  23  24/07/2015                     260
# 8    14                  19  06/07/2015                     155
# 9     1                  22  13/07/2015                     235
# 10   20                   1  20/07/2015                     260
# 11   20                   1  14/07/2015                     260
# 12   20                  11  15/07/2015                     260
# 13    3                  11  15/07/2015                     179
# ...

# %% [markdown]
# **Absenteeism in hours will be our DEPENDENT variable. All other cols rep. Independent variables.**

# %% [markdown]
# # Removing Irrelevant Data
#
# ## Drop 'ID':

# %%
df.drop(['ID'], axis = 1) # axis = 1 means that we want to remove a column along the horizontal axis
# Out:
#      Reason for Absence        Date  Transportation Expense  Distance to Work  \
# 0                    26  07/07/2015                     289                36
# 1                     0  14/07/2015                     118                13
# 2                    23  15/07/2015                     179                51
# 3                     7  16/07/2015                     279                 5
# 4                    23  23/07/2015                     289                36
# 5                    23  10/07/2015                     179                51
# 6                    22  17/07/2015                     361                52
# 7                    23  24/07/2015                     260                50
# 8                    19  06/07/2015                     155                12
# 9                    22  13/07/2015                     235                11
# 10                    1  20/07/2015                     260                50
# ...

# %%
df = df.drop(['ID'], axis = 1) # axis = 1 means that we want to remove a column along the horizontal axis

# %%
df
# Out:
#      Reason for Absence        Date  Transportation Expense  Distance to Work  \
# 0                    26  07/07/2015                     289                36
# 1                     0  14/07/2015                     118                13
# 2                    23  15/07/2015                     179                51
# 3                     7  16/07/2015                     279                 5
# 4                    23  23/07/2015                     289                36
# 5                    23  10/07/2015                     179                51
# 6                    22  17/07/2015                     361                52
# 7                    23  24/07/2015                     260                50
# 8                    19  06/07/2015                     155                12
# 9                    22  13/07/2015                     235                11
# 10                    1  20/07/2015                     260                50
# ...

# %% [markdown]
# Forgetting to make a copy of your data can be bad.
#
# ## Exercise: Drop 'Age'

# %%
df
# Out:
#      Reason for Absence        Date  Transportation Expense  Distance to Work  \
# 0                    26  07/07/2015                     289                36
# 1                     0  14/07/2015                     118                13
# 2                    23  15/07/2015                     179                51
# 3                     7  16/07/2015                     279                 5
# 4                    23  23/07/2015                     289                36
# 5                    23  10/07/2015                     179                51
# 6                    22  17/07/2015                     361                52
# 7                    23  24/07/2015                     260                50
# 8                    19  06/07/2015                     155                12
# 9                    22  13/07/2015                     235                11
# 10                    1  20/07/2015                     260                50
# ...

# %%
dfNoAge = df.drop(['Age'], axis = 1)

# %%
dfNoAge
# Out:
#      Reason for Absence        Date  Transportation Expense  Distance to Work  \
# 0                    26  07/07/2015                     289                36
# 1                     0  14/07/2015                     118                13
# 2                    23  15/07/2015                     179                51
# 3                     7  16/07/2015                     279                 5
# 4                    23  23/07/2015                     289                36
# 5                    23  10/07/2015                     179                51
# 6                    22  17/07/2015                     361                52
# 7                    23  24/07/2015                     260                50
# 8                    19  06/07/2015                     155                12
# 9                    22  13/07/2015                     235                11
# 10                    1  20/07/2015                     260                50
# ...

# %% [markdown]
# ## Determining Reasons For Absence

# %%
df['Reason for Absence']
# Out:
# 0      26
# 1       0
# 2      23
# 3       7
# 4      23
# 5      23
# 6      22
# 7      23
# 8      19
# 9      22
# 10      1
# 11      1
# 12     11
# 13     11
# 14     23
# 15     14
# 16     23
# 17     21
# 18     11
# 19     23
# 20     10
# 21     11
# 22     13
# 23     28
# 24     18
# 25     25
# 26     23
# 27     28
# 28     18
# 29     23
#        ..
# 670    28
# 671    19
# 672    14
# 673    27
# 674    22
# 675    19
# 676    28
# 677     8
# 678    26
# 679    13
# 680    28
# 681    14
# 682    19
# 683    22
# 684    27
# 685    23
# 686     5
# 687    28
# 688     0
# 689    27
# 690     0
# 691    16
# 692    10
# 693    10
# 694    22
# 695    10
# 696     6
# 697    10
# 698    23
# 699    28
# Name: Reason for Absence, Length: 700, dtype: int64
